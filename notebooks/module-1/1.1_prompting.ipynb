# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon has no government or cities, so it has no capital. If you’re thinking of fiction or future plans, some stories coin fictional lunar capitals (e.g., “Luna City”), but none exist in reality.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Artemis City.
#
# - Location: Perched on the rim of Shackleton Crater in the lunar south pole region, where near-constant sunlight at the perimeter feeds solar farms and keeps the citadel warm enough for glass and metal to work in harmony with ice.
#
# - Government: The Crescent Assembly rules from the central Citadel, a ringed hub around a towering crescent-shaped palace. Delegates represent mining, science, industry, and lunar towns, all guided by a lunar council that rotates leadership with the cycles of the local solar day.
#
# - Architecture: A blend of crystalline domes, basalt-block arches, and latticeworks of transparent regolith. The centerpiece is the Crescent Citadel, a glass-and-black-stone throne room that glows softly when solar power flows through the city’s network of heliostats and photon-lattice corridors.
#
# - Economy: Water ice from permanently shadowed craters is refined into life-support loops, fuel, and industrial print-stock. Artemis City is a hub for 3D-printed habitat modules, lunar mining logistics, and orbital transfer coordination.
#
# - Transportation: Quiet mag-lev tramways thread through a network of surface plazas, with vertical ascent towers that deploy glide-rails to orbit. Personal transmodes glide along energy threads above the streets, leaving no exhaust.
#
# - Culture: A strong emphasis on science, art, and exploration. The annual Solstice Festival features crystal-light performances, ice-sculpted sculptures, and auroral symphonies cast across the polar sky.
#
# - Notable features: The Observatory Spire tracks solar storms and cosmic events; the Iceforge Market trades in rare lunar minerals and biotech goods; public parks reveal “eternal daylight” microclimates created by reflective glass and sun-orbits.
#
# If you’d like, I can write a short scene set in Artemis City or design an alternate capital (e.g., Selene Gate on the Mare Imbrium rim or Crater Helios in a different region).

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunopolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Lunaris Prime
# Location: Near-side equatorial basin of Mare Tranquillitatis, atop a shielded basalt plateau with an orbital transit hub.
# Vibe: neon bureaucratic metropolis
# Economy: Ice mining and water processing; solar energy production; space manufacturing and logistics

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
