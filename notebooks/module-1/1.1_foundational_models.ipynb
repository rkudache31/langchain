# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model link->https://academy.langchain.com/courses/take/foundation-introduction-to-langchain-python/lessons/71234850-lesson-1-foundational-models

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano",
                       temperature=1.0)

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 response = model.invoke("What's the capital of the Moon?")
#       3 response
#
# NameError: name 'model' is not defined

# %%
print(response.content)
# Out:
# There’s no capital. The Moon isn’t a country or political entity, so it has no government or capital city.
#
# If you were going for a joke: the capital letter of the word "Moon" is M. If you had a specific fictional universe in mind, tell me which one and I can name its capital or suggest a plausible one.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DtiBKg8IWdSCrp916Kw6dne07VQoe',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 523,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 448,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 536}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or city and has no government or capital.
#
# If you meant something else:
# - If you’re asking about capital letters, the capital letter of the word "Moon" is M.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[18], line 3
#       1 model = init_chat_model(model="claude-sonnet-4-5")
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1768, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1766     data = self._create(payload)
#    1767 except anthropic.BadRequestError as e:
# -> 1768     _handle_anthropic_bad_request(e)
#    1769 return self._format_output(data, **kwargs)
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1766, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1764 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1765 try:
# -> 1766     data = self._create(payload)
#    1767 except anthropic.BadRequestError as e:
#    1768     _handle_anthropic_bad_request(e)
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1431, in ChatAnthropic._create(self, payload)
#    1429 if "betas" in payload:
#    1430     return self._client.beta.messages.create(**payload)
# -> 1431 return self._client.messages.create(**payload)
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1018, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1011 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1012     warnings.warn(
#    1013         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1014         UserWarning,
#    1015         stacklevel=3,
#    1016     )
# -> 1018 return self._post(
#    1019     "/v1/messages",
#    1020     body=maybe_transform(
#    1021         {
#    1022             "max_tokens": max_tokens,
#    1023             "messages": messages,
#    1024             "model": model,
#    1025             "cache_control": cache_control,
#    1026             "container": container,
#    1027             "inference_geo": inference_geo,
#    1028             "metadata": metadata,
#    1029             "output_config": output_config,
#    1030             "service_tier": service_tier,
#    1031             "stop_sequences": stop_sequences,
#    1032             "stream": stream,
#    1033             "system": system,
#    1034             "temperature": temperature,
#    1035             "thinking": thinking,
#    1036             "tool_choice": tool_choice,
#    1037             "tools": tools,
#    1038             "top_k": top_k,
#    1039             "top_p": top_p,
#    1040         },
#    1041         message_create_params.MessageCreateParamsStreaming
#    1042         if stream
#    1043         else message_create_params.MessageCreateParamsNonStreaming,
#    1044     ),
#    1045     options=make_request_options(
#    1046         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1047     ),
#    1048     cast_to=Message,
#    1049     stream=stream or False,
#    1050     stream_cls=Stream[RawMessageStreamEvent],
#    1051 )
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File F:\AI\Langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CcKAYnB3bsyJP9Uh46yse'}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question that plays on our understanding of what a capital city is!
#
# Since the Moon is not a country or a populated territory with a government, it **does not have a capital city**.
#
# A capital city is typically the seat of government for a country or region. The Moon, as a celestial body, doesn't fit that description.

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='f568475b-05a9-4ff6-a028-299c39e45651'),
#               AIMessage(content='There isn’t one. The Moon has no government or official cities, so it has no capital. If you’re thinking of a fictional or future scenario, you could invent a capital (e.g., a city called Luna City or Selene) for your story. Real-world governance would be governed by international law and any future agreements, not a capital city.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 849, 'prompt_tokens': 13, 'total_tokens': 862, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DtiOUIlm4c37nOpdTY9tDWzDADqQZ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ef1ac-491f-7bf1-94d4-c5eaf7390cb9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 849, 'total_tokens': 862, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon has no government or official cities, so it has no capital. If you’re thinking of a fictional or future scenario, you could invent a capital (e.g., a city called Luna City or Selene) for your story. Real-world governance would be governed by international law and any future agreements, not a capital city.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='2bb37414-e082-4c16-8860-23fb7b7ab8c9'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='47864b62-f134-4093-8e4f-d69e85c4ac61', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='3ad1fb26-8900-4117-98f5-e179632f622c'),
#               AIMessage(content='A quick note: there’s no real capital of the Moon. Luna City is a fictional concept you might find in sci‑fi or worldbuilding. If you’d like, I can treat it as a plausible fictional setting and flesh it out. Here’s a compact worldbuilding sketch you could use or adapt.\n\nLuna City: a plausible fictional capital for a lunar federation\n\n- Concept image\n  - A permanent, self-sustaining settlement serving as the political and scientific heart of a lunar federation or confederation.\n  - Located where it can balance sunlight, shielding, and access to water ice—commonly envisioned near the lunar south pole on a sunlit ridge with nearby shadowed craters.\n\n- Location and geography\n  - Primary site: near the rim of Shackleton-like craters at the south pole, ensuring:\n    - Long periods of near-continuous solar power from high-elevation sunlit exposures.\n    - Proximity to water ice in permanently shadowed regions for life support and fuel.\n  - Secondary sites: polar highlands or equatorial lava tubes for radiation shielding and stable temperatures.\n\n- Governance and institutions\n  - The Lunar Confederation’s capital, Luna City hosts:\n    - The Lunar Council (legislature) and an executive Office of the Governor-General.\n    - Ministries of Resources, Science, Infrastructure, Health, and Education.\n    - A Lunar Legal Code built around ISRU (in-situ resource use), environmental stewardship, and international cooperation.\n  - International/planetary partnerships with Earth-based agencies and private companies.\n\n- Infrastructure and architecture\n  - Modular, 3D-printed habitats shielded by regolith for radiation protection; central energy plant; water processing and air recycling facilities.\n  - Dome districts for agriculture (greenhouses with hydroponics/algae bioreactors), living quarters, and research labs.\n  - Energy: solar arrays on sunlit features, with compact nuclear microreactors as backups; energy storage in advanced batteries or fuel cells.\n  - Transportation hubs: surface rovers, hopping drones, and a cargo gradient from a gateway in low lunar orbit or a nearby depot.\n\n- Economy and ISRU\n  - Core ISRU outputs: water ice extraction and processing into oxygen and hydrogen; regolith mining for metals and construction materials; possible helium-3 or other ISRU-based energy products.\n  - Sectors: research and development, planetary science, materials testing, lunar tourism (with careful environmental guidelines), and infrastructure construction for other settlements.\n  - Supply chain: Earth-Moon logistics with regular cargo landers; in-situ production reduces dependence on Earth.\n\n- Daily life and culture\n  - Population scale: tens of thousands to begin, growing with new settlements linked to Luna City.\n  - Timekeeping: coordinated with Earth time for governance and trade, while local routines adapt to the 1/6 g environment and the lunar day-night cycle.\n  - Housing and social life: communal and family housing clusters, schools with microgravity labs, virtual/augmented reality libraries, and cultural centers that celebrate Earth heritage and lunar discovery.\n  - Health and safety: radiation shielding, strict dust control, mental health support, and regular health screenings.\n  - Education and research: universities and research institutes focused on lunar geology, ISRU, biotechnology for closed-loop life support, and materials science.\n\n- Challenges and design notes\n  - Radiation and micrometeoroids: thick shielding, sheltered corridors, and redundant life-support systems.\n  - Psychological health: long-duration isolation, daylight cycles, and community activities to maintain morale.\n  - Resource balance: securing a steady water/ice supply, maintaining greenhouses, and ensuring sustainable energy storage.\n  - Resupply risk: dependency on Earth for some components; plan for rapid on-site manufacturing and 3D printing.\n\n- Quick vignette (a day in Luna City)\n  ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional capital for the Moon (a common setting in sci‑fi and world‑building). If you had a specific universe in mind (a book, game, movie, etc.), tell me and I can tailor it. Below is a detailed, self-contained concept you can drop into a story or game.
#
# Overview
# - Name: Luna City (often shortened to “Luna” or “the Capital” in official discourse)
# - Where it sits: a major settlement at the rim of a polar or near-polar crater (often Shackleton or a similar large crater), chosen for access to water ice in the shadowed floors and generous solar exposure along the rim.
# - Role: political and cultural capital of the Moon; headquarters for the Lunar Commonwealth (or Lunar Confederation, depending on your world’s politics); hub for science, education, diplomacy, and finance.
# - Tone/style: a blend of utilitarian engineering, high-tech urbanism, and a distinct lunar culture that blends Earth roots with frontier practicality. Think “Lunarpunk” meets archology.
#
# Government and politics
# - Political structure: Luna City hosts the central government of the Lunar Commonwealth. The city contains the main seats of governance: the Lunar Assembly (legislature), the Executive Council (prime minister/governor and ministry chiefs), and the Judiciary District (courts and tribunals).
# - Representation: districts correspond to lunar regions (rim districts, polar ice districts, crater-floor districts, and orbital-facing districts). Each district sends delegates to the Assembly; the Assembly elects a Prime Secretary who leads the Executive Council.
# - Legal framework: constitutional framework designed for a low-gravity, radiation-protected society; laws emphasize resource stewardship (water ice, regolith, solar energy), autonomous industry, and planetary protection.
# - Earth relation: Luna City maintains a formal diplomatic relationship with Earth governments (Terran Confederation or United Earth) and hosts the Lunar-Earth Council, a body for trade, security, and science collaboration.
#
# Geography and environment
# - Location features: the city sits inside or along the rim of a large crater to maximize solar exposure (on the rim) while leveraging subsurface ice pockets (in the crater floor) for water and fuel. Clever shielding and geology-informed layouts minimize radiation exposure.
# - Climate and day-night: no atmosphere, so radiation and micrometeorites are managed with shielding. The Moon’s ~29.5-day day means an artificial diurnal cycle is common inside habitats: a controlled “day” and “night” schedule to preserve circadian health.
# - Water and resources: water ice mined from crater-floor deposits; regolith processed into building materials; helium-3 and refined metals sourced from lunar regolith and small asteroid/comet supply.
#
# City layout and districts
# - Central government district: the Civic Spire complex, the Assembly Hall, interfaith/neutral forum, and the headquarters of key ministries.
# - Administrative core: post office, archives, and the Lunar Archive—a vast, partially underground repository of lunar history and science.
# - Residential belts: multi-layered, gravity-assisted living towers with shared amenities, medical bays, schools, and community gardens; neighborhoods are designed for 20–60 thousand residents each.
# - Science and education quarter: lunar universities, research institutes, space medicine labs, and robotics/AI labs; heavy emphasis on closed-loop life support, in-situ resource utilization, and materials science.
# - Industrial zone: manufacturing using in-situ resources, 3D-printed regolith-based materials, battery and life-support systems, drone and vehicle manufacturing, and repair hubs.
# - Ice and water district: extraction facilities, water purification plants, and cryo-storage; power plants and cooling systems integrated with the ice-processing sites.
# - Cultural and civic quarter: museums, theaters, galleries, music venues, and digital-memorial spaces that celebrate lunar pioneers and Earth-Luna heritage.
# - Transportation hubs: transit centers for surface maglev/tram systems, subterranean tunnels, and a lunar elevator or cable-runner connecting to near-orbit depots.
# - Green and data commons: vertical farms and algae bioreactors for food and air recycling; large-scale data centers powered by solar arrays and energy storage.
#
# Architecture and technology
# - Aesthetic: a mix of robust, modular architecture with elements of glass/ceramic composites, lattice catenary supports, and inflatable modular habitats reinforced with regolith-based armor. Transparency is used where shielding allows, with smart glass that can tint to regulate solar heat.
# - Materials: regolith-concrete, lunar glass, nano-coated polymers for dust resistance, and ultralight composites for load-bearing supports in low gravity.
# - Energy systems: primary power from large solar farms on the crater rim, with energy storage in advanced batteries and fuel cells; backup microreactors or compact fission/fusion reactors in shielded facilities for night or eclipse periods.
# - Robotics and AI: autonomous cleaning, maintenance, mining, construction, and security bots; AI manages life support, resource allocation, traffic control, and emergency responses.
# - Transportation tech: surface maglev or wheel-based shuttles, tunnel-bored transit, drone delivery corridors, and possibly a light cosmic rail to rapid-leap between moons and Earth.
#
# Society and culture
# - Demographics: mix of Earth-born settlers, second-generation lunar citizens, engineers, scientists, and artists. A notable portion are born on the Moon who arrive with families from Earth institutions.
# - Daily life: compact, high-function neighborhoods; shared recreational domes; strong communal norms around resource stewardship, education, and environmental health.
# - Education: mandatory STEM-and-humanities hybrid curricula; apprenticeship tracks in mining, life support, AI management, and agronomy; public museums and science centers are central to civic life.
# - Culture and values: resilience, collaboration across districts, and a strong emphasis on sustainability and transparency. Art and music blend Earth traditions with lunar textures and sounds, often featuring the hum of solar lamps and the quiet of vacuum. Festivals celebrate lunar cycles, water ice discoveries, and milestone space missions.
# - Religion and philosophy: secular civic religion with ceremonial spaces for reflection; philosophical movements emphasize “unity through scarcity” or “harmonizing human life with the lunar environment.”
#
# Economy and resources
# - Core industries: water ice extraction and purification, in-situ resource utilization (ISRU) for construction materials, solar energy production and storage, high-precision manufacturing, and biotech for life support.
# - Trade: lunar exports of high-purity water, helium-3 (if present in your lore), refined minerals, machine parts, and AI-enabled services; Earth-Luna trade corridors for food, medicine, and cultural artifacts.
# - Currency and finance: a Lunar Credit or Commonwealth Credit backed by resource reserves and energy futures; many transactions are digital, with robust cybersecurity.
# - Tourism: controlled, educational tourism to ice caves, solar farms, and museum districts; virtual reality experiences that simulate Earth’s landscapes.
#
# Science, security, and infrastructure
# - Research focus: closed-loop life support tech, radiation shielding, AI governance, renewable energy optimization, and deep-space propulsion studies.
# - Security: a Lunar Peace and Security Service with civilian oversight; cyber-defense units protect critical infrastructure; emergency response teams operate around the clock.
# - Resilience architecture: multi-layered shielding, redundant life-support networks, modular districts that can be evacuated or repurposed in emergencies.
#
# Interplanetary and Earth relations
# - Earth connection: regular cargo and passenger shuttles; Earth-based universities partner with Lunar institutions; Earth governance frames policy with the Moon and funds large-scale lunar projects.
# - Diplomacy: Luna City hosts international lunar summits, scientific collaborations, and trade agreements; crisis communication lines with Earth ensure rapid response to space weather events or supply disruptions.
#
# History and lore (short arc)
# - Founding: initial settlement in the late 21st or early 22nd century, focused on scientific outposts and water ice mining.
# - Rise to capital: after establishing autonomous governance and a stable economy, Luna City becomes the political and cultural hub of lunar civilization.
# - Current era: a mature, technologically advanced capital with a strong emphasis on sustainability, exploration, and Earth-Luna partnership.
#
# Landmarks and districts (sample)
# - The Civic Spire: central government complex and ceremonial seat of power.
# - The Archive Crater: a subterranean and above-ground archive housing lunar history, data vaults, and research libraries.
# - The Ice Gate: entrance to water-ice facilities with observation decks showing lunar geology and ice processing.
# - The Daylight Ring: solar farms encircling the rim with a public promenade and energy-harvesting sculpture garden.
# - The Wake Market: a mixed-use district with markets, eateries, and cultural performances.
# - The Green Belt: vertical farms and algae bioreactors providing fresh food and breathable air.
# - The Lunar Opera House: a flagship cultural venue blending Earth theatrical traditions with lunar-inspired performances.
#
# Story hooks and ideas
# - A water-ice discovery reveals a water-rich pocket that prompts a political crisis and inter-district tensions.
# - A breakthrough in ISRU allows mass production of durable regolith-based construction, transforming the city’s expansion plans.
# - An Earth-Earth-Luna treaty negotiates new access to rare resources; a rogue faction threatens the unity of the Lunar Commonwealth.
# - A near-miss with solar storms tests the city’s energy storage and emergency protocols, forcing communities to rely on old-school ingenuity.
# - An educator-astronaut returns with a mysterious artifact that hints at pre-lunar civilizations, upending the city’s understanding of its own history.
#
# Tips for realism and immersion
# - Keep the Moon’s realities in mind: no breathable air, extreme temperature swings, radiation, micrometeorites, and dust—your architecture and life-support systems should reflect this.
# - Use circadian-friendly routines in public life (artificial day/night cycles, structured shift work, communal downtime).
# - Emphasize resource stewardship: water, energy, and materials are precious and carefully managed.
# - Blend high-tech systems with tangible, tactile environments—people feel the weight (or lack) of gravity, hear various mechanical hums, and interact with screens and physical interfaces differently than on Earth.
# - Show Earth-Luna dynamics not just as politics but as culture, trade, and collaboration: education exchanges, artist residencies, joint research programs.
#
# If you want, I can tailor this to a specific vibe (hard sci-fi, space opera, cyberpunk, steampunk lunar variant, etc.), set a precise year or timeline, or write a sample scene in Luna City. Would you like a particular genre or a short prologue set there?
